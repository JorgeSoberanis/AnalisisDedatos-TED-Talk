# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
df = pd.read_csv("TED.csv")
df.head()
# Out:
#                                                title                author  \
# 0      Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1        The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2     How play can spark new ideas for your business         Martin Reeves
# 3  Why is China appointing judges to combat clima...     James K. Thornton
# 4     Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
#
#              date   views  likes  \
# 0   December 2021  404000  12000
# 1   February 2022  214000   6400
# 2  September 2021  412000  12000
# 3    October 2021  427000  12000
# 4    October 2021    2400     72
#
#                                                 link  Unnamed: 6  Unnamed: 7  \
# 0  https://ted.com/talks/ozawa_bineshi_albert_cli...         NaN         NaN
# 1  https://ted.com/talks/sydney_iaukea_the_dark_h...         NaN         NaN
# ...

# %% [markdown]
# #### Vamos a ordenar los datos de mayor a menor numero de likes:

# %%
orden_likes = df.sort_values("likes", ascending=False)
orden_likes.head()
# Out:
#                                            title            author  \
# 5436                 Do schools kill creativity?  Sir Ken Robinson
# 4084    Your body language may shape who you are         Amy Cuddy
# 2958  Inside the mind of a master procrastinator         Tim Urban
# 4605                  The power of vulnerability       Brené Brown
# 4765            How great leaders inspire action       Simon Sinek
#
#                 date     views    likes  \
# 5436   February 2006  72000000  2100000
# 4084       June 2012  64000000  1900000
# 2958   February 2016  60000000  1800000
# 4605       June 2010  56000000  1700000
# 4765  September 2009  57000000  1700000
#
#                                                    link  Unnamed: 6  \
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...         NaN
# 4084  https://ted.com/talks/amy_cuddy_your_body_lang...         NaN
# 2958  https://ted.com/talks/tim_urban_inside_the_min...         NaN
# ...

# %% [markdown]
# #### Vamos a ordenar los datos de menor a mayor numero de likes

# %%
orden_vistas = df.sort_values("likes", ascending=True)
orden_vistas.head()
# Out:
#                                                   title  \
# 3039                                 Year In Ideas 2015
# 613                  Post-Pandemic Paradise in Rapa Nui
# 552                                      Virtual Worlds
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
#
#                                 author           date  views  likes  \
# 3039                               NaN  December 2015    532     15
# 613                          Far Flung   October 2020   1200     37
# 552                          Far Flung  November 2020   1300     39
# 1692       Deutsche Philharmonie Merck  November 2018   1300     40
# 1064  Findlay Napier and Gillian Frame      July 2019   1300     40
#
#                                                    link  Unnamed: 6  \
# 3039           https://ted.com/talks/year_in_ideas_2015         NaN
# 613   https://ted.com/talks/far_flung_post_pandemic_...         NaN
# ...

# %% [markdown]
# #### Vamos a ordenar los autores de manera alfabetica:

# %%
orden_autores = df.sort_values("author", ascending=True)

# %% [markdown]
# #### Sacamos datos random con el atributo sample

# %%
datamuestra = df.sample(200, random_state =None)
datamuestra.head()
# Out:
#                                                   title          author  \
# 5408                 Meet the future of cancer research      Eva Vertes
# 77    How to deal with your insomnia — and finally g...     Matt Walker
# 2843                          My love letter to cosplay     Adam Savage
# 993    The Tower of Epiphany | Think Like A Coder, Ep 7  Alex Rosenthal
# 3503                 The 1s and 0s behind cyber warfare     Chris Domas
#
#                date    views  likes  \
# 5408  February 2005  1100000  35000
# 77    December 2021   311000   9300
# 2843  February 2016  3000000  92000
# 993   February 2020   447000  13000
# 3503   October 2013  1100000  34000
#
#                                                    link  Unnamed: 6  \
# 5408  https://ted.com/talks/eva_vertes_meet_the_futu...         NaN
# 77    https://ted.com/talks/matt_walker_how_to_deal_...         NaN
# 2843  https://ted.com/talks/adam_savage_my_love_lett...         NaN
# ...

# %%
datamuestra.memory_usage(deep=True)
# Out:
# Index          1600
# title         20617
# author        14332
# date          13648
# views          1600
# likes          1600
# link          26847
# Unnamed: 6     1600
# Unnamed: 7     1600
# Unnamed: 8     1600
# Unnamed: 9     1600
# dtype: int64

# %%
datamuestra.columns
# Out:
# Index(['title', 'author', 'date', 'views', 'likes', 'link', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
df_columns = [
    'titulo',
    'autor',
    'fecha',
    'visualisaciones',
    'likes',
    'link',
    'NAN6',
    'NAN7',
    'NAN8',
    'NAN9',
]

# %%
datamuestra.columns = df_columns

# %%
print(datamuestra.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200 entries, 5408 to 3653
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   titulo           200 non-null    object
#  1   autor            200 non-null    object
#  2   fecha            200 non-null    object
#  3   visualisaciones  200 non-null    int64
#  4   likes            200 non-null    int64
#  5   link             200 non-null    object
#  6   NAN6             0 non-null      float64
#  7   NAN7             0 non-null      float64
#  8   NAN8             0 non-null      float64
#  9   NAN9             0 non-null      float64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 17.2+ KB
# None
